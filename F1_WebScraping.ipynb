# %%
import requests 
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
url_2022 = 'https://www.formula1.com/en/results.html/2022/races.html'
url_2023 = 'https://www.formula1.com/en/results.html/2023/races.html'

# %%
response = requests.get(url_2022)  # Sends a GET request to the specified 'url_2022' using the 'requests.get()' method, storing the response.

table = soup.find('table')  # Using BeautifulSoup's 'find()' method to locate and retrieve the first 'table' element from the parsed HTML content stored in the 'soup' variable.

# %%
column_names = []  # Initialize an empty list to store column names.

# Iterating through each 'tr' (table row) within the 'table' HTML element.
for row in table.find_all('tr'):
    columns = row.find_all('th')  # Extracting all 'th' (table header) elements within the row.

    # Iterating through each column in the row.
    for column in columns:
        if column.get_text() == '':  # Checking if the column text is empty.
            continue  # If the column text is empty, skip to the next iteration.

        column_names.append(column.get_text())  # If the column text is not empty, add it to the 'column_names' list.

# %%
column_names
# Out:
# ['Grand Prix', 'Date', 'Winner', 'Car', 'Laps', 'Time']

# %%
data = []  # Initialize an empty list to store the table data.

# Iterate through each 'tr' (table row) within the 'table' HTML element.
for row in table.find_all('tr'):
    columns = row.find_all('td')  # Extract all 'td' (table data/cell) elements within the row.

    row_data = []  # Initialize an empty list to store the data for each row.

    # Iterate through each column (table cell) in the row.
    for column in columns:
        val = column.get_text()  # Get the text content of the column.
        val = val.strip()  # Remove leading and trailing whitespaces.
        val = val.replace('\n', ' ')  # Replace newline characters with spaces.

        if val == '':  # If the value is empty after formatting, skip to the next iteration.
            continue

        row_data.append(val)  # Append the formatted value to the 'row_data' list.

    if row_data != []:  # If the 'row_data' list is not empty (i.e., if it contains values):
        data.append(row_data)  # Append the row data to the 'data' list.

# %%
data
# Out:
# [['Bahrain',
#   '20 Mar 2022',
#   'Charles Leclerc LEC',
#   'Ferrari',
#   '57',
#   '1:37:33.584'],
#  ['Saudi Arabia',
#   '27 Mar 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '50',
#   '1:24:19.293'],
#  ['Australia',
#   '10 Apr 2022',
#   'Charles Leclerc LEC',
#   'Ferrari',
#   '58',
#   '1:27:46.548'],
#  ['Emilia Romagna',
#   '24 Apr 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '63',
#   '1:32:07.986'],
#  ['Miami',
#   '08 May 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '57',
#   '1:34:24.258'],
#  ['Spain',
#   '22 May 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '66',
#   '1:37:20.475'],
#  ['Monaco',
#   '29 May 2022',
#   'Sergio Perez PER',
#   'Red Bull Racing RBPT',
#   '64',
#   '1:56:30.265'],
#  ['Azerbaijan',
#   '12 Jun 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '51',
#   '1:34:05.941'],
#  ['Canada',
#   '19 Jun 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '70',
#   '1:36:21.757'],
#  ['Great Britain',
#   '03 Jul 2022',
#   'Carlos Sainz SAI',
#   'Ferrari',
#   '52',
#   '2:17:50.311'],
#  ['Austria',
#   '10 Jul 2022',
#   'Charles Leclerc LEC',
#   'Ferrari',
#   '71',
#   '1:24:24.312'],
#  ['France',
#   '24 Jul 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '53',
#   '1:30:02.112'],
#  ['Hungary',
#   '31 Jul 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '70',
#   '1:39:35.912'],
#  ['Belgium',
#   '28 Aug 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '44',
#   '1:25:52.894'],
#  ['Netherlands',
#   '04 Sep 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '72',
#   '1:36:42.773'],
#  ['Italy',
#   '11 Sep 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '53',
#   '1:20:27.511'],
#  ['Singapore',
#   '02 Oct 2022',
#   'Sergio Perez PER',
#   'Red Bull Racing RBPT',
#   '59',
#   '2:02:20.238'],
#  ['Japan',
#   '09 Oct 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '28',
#   '3:01:44.004'],
#  ['United States',
#   '23 Oct 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '56',
#   '1:42:11.687'],
#  ['Mexico',
#   '30 Oct 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '71',
#   '1:38:36.729'],
#  ['Brazil',
#   '13 Nov 2022',
#   'George Russell RUS',
#   'Mercedes',
#   '71',
#   '1:38:34.044'],
#  ['Abu Dhabi',
#   '20 Nov 2022',
#   'Max Verstappen VER',
#   'Red Bull Racing RBPT',
#   '58',
#   '1:27:45.914']]

# %%
len(data)
# Out:
# 22

# %%
response = requests.get(url_2023)
soup = BeautifulSoup(response.content, 'html.parser')
table=soup.find('table')

# %%
# Loop through each 'tr' (table row) in the 'table' HTML element.
for row in table.find_all('tr'):
    columns = row.find_all('td')  # Retrieve all 'td' (table data/cell) elements within the row.

    row_data = []  # Initialize an empty list to store the data for each row.

    # Iterate through each column (table cell) in the row.
    for column in columns:
        val = column.get_text()  # Get the text content of the column.
        val = val.strip()  # Remove leading and trailing whitespaces.
        val = val.replace('\n', ' ')  # Replace newline characters with spaces.

        if val == '':  # If the value is empty after formatting, skip to the next iteration.
            continue

        row_data.append(val)  # Append the formatted value to the 'row_data' list.

    if row_data != []:  # If the 'row_data' list is not empty (i.e., if it contains values):
        data.append(row_data)  # Append the row data to the 'data' list.

# %%
len(data)
# Out:
# 40

# %%
df = pd.DataFrame(data, columns=column_names)

# %%
df.head()
# Out:
#        Grand Prix         Date               Winner                   Car  \
# 0         Bahrain  20 Mar 2022  Charles Leclerc LEC               Ferrari
# 1    Saudi Arabia  27 Mar 2022   Max Verstappen VER  Red Bull Racing RBPT
# 2       Australia  10 Apr 2022  Charles Leclerc LEC               Ferrari
# 3  Emilia Romagna  24 Apr 2022   Max Verstappen VER  Red Bull Racing RBPT
# 4           Miami  08 May 2022   Max Verstappen VER  Red Bull Racing RBPT
#
#   Laps         Time
# 0   57  1:37:33.584
# 1   50  1:24:19.293
# 2   58  1:27:46.548
# 3   63  1:32:07.986
# 4   57  1:34:24.258

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d %b %Y')
df['Laps'] = df['Laps'].astype(int)

# %%
df.head()
# Out:
#        Grand Prix       Date               Winner                   Car  Laps  \
# 0         Bahrain 2022-03-20  Charles Leclerc LEC               Ferrari    57
# 1    Saudi Arabia 2022-03-27   Max Verstappen VER  Red Bull Racing RBPT    50
# 2       Australia 2022-04-10  Charles Leclerc LEC               Ferrari    58
# 3  Emilia Romagna 2022-04-24   Max Verstappen VER  Red Bull Racing RBPT    63
# 4           Miami 2022-05-08   Max Verstappen VER  Red Bull Racing RBPT    57
#
#           Time
# 0  1:37:33.584
# 1  1:24:19.293
# 2  1:27:46.548
# 3  1:32:07.986
# 4  1:34:24.258

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Grand Prix  40 non-null     object
#  1   Date        40 non-null     datetime64[ns]
#  2   Winner      40 non-null     object
#  3   Car         40 non-null     object
#  4   Laps        40 non-null     int32
#  5   Time        40 non-null     object
# dtypes: datetime64[ns](1), int32(1), object(4)
# memory usage: 1.8+ KB

# %%
df.to_csv('f1_race_results_web_source.csv', index=False)

# %%
df2 = pd.read_csv("driver_detail.csv")

# %%
df2.head()
# Out:
#    DRIVERID   DRIVERREF  NUMBER CODE  FORENAME     SURNAME         DOB  \
# 0         1    hamilton    44.0  HAM     Lewis    Hamilton  01-07-1985
# 1         2    heidfeld     NaN  HEI      Nick    Heidfeld  05-10-1977
# 2         3     rosberg     6.0  ROS      Nico     Rosberg   6/27/1985
# 3         4      alonso    14.0  ALO  Fernando      Alonso   7/29/1981
# 4         5  kovalainen     NaN  KOV    Heikki  Kovalainen  10/19/1981
#
#   NATIONALITY                                             URL
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
# Concatenate the 'forename', 'surname', and 'code' columns in both DataFrames
df2['concatenated'] = df2['FORENAME'] + " " + df2['SURNAME'] + " "+ df2['CODE']

# %%
result_df = pd.merge(df, df2, left_on='Winner', right_on='concatenated', how='inner')

# %%
result_df.drop(["DRIVERID", "DRIVERREF", "NUMBER", "CODE", "FORENAME", "SURNAME", "concatenated"], axis=1, inplace=True)

# %%
result_df
# Out:
#         Grand Prix       Date               Winner  \
# 0          Bahrain 2022-03-20  Charles Leclerc LEC
# 1        Australia 2022-04-10  Charles Leclerc LEC
# 2          Austria 2022-07-10  Charles Leclerc LEC
# 3     Saudi Arabia 2022-03-27   Max Verstappen VER
# 4   Emilia Romagna 2022-04-24   Max Verstappen VER
# 5            Miami 2022-05-08   Max Verstappen VER
# 6            Spain 2022-05-22   Max Verstappen VER
# 7       Azerbaijan 2022-06-12   Max Verstappen VER
# 8           Canada 2022-06-19   Max Verstappen VER
# 9           France 2022-07-24   Max Verstappen VER
# 10         Hungary 2022-07-31   Max Verstappen VER
# 11         Belgium 2022-08-28   Max Verstappen VER
# 12     Netherlands 2022-09-04   Max Verstappen VER
# 13           Italy 2022-09-11   Max Verstappen VER
# 14           Japan 2022-10-09   Max Verstappen VER
# 15   United States 2022-10-23   Max Verstappen VER
# 16          Mexico 2022-10-30   Max Verstappen VER
# 17       Abu Dhabi 2022-11-20   Max Verstappen VER
# 18         Bahrain 2023-03-05   Max Verstappen VER
# 19       Australia 2023-04-02   Max Verstappen VER
# 20           Miami 2023-05-07   Max Verstappen VER
# 21          Monaco 2023-05-28   Max Verstappen VER
# 22           Spain 2023-06-04   Max Verstappen VER
# 23          Canada 2023-06-18   Max Verstappen VER
# 24         Austria 2023-07-02   Max Verstappen VER
# 25   Great Britain 2023-07-09   Max Verstappen VER
# 26         Hungary 2023-07-23   Max Verstappen VER
# 27         Belgium 2023-07-30   Max Verstappen VER
# 28     Netherlands 2023-08-27   Max Verstappen VER
# 29           Italy 2023-09-03   Max Verstappen VER
# 30           Japan 2023-09-24   Max Verstappen VER
# 31           Qatar 2023-10-08   Max Verstappen VER
# 32   United States 2023-10-22   Max Verstappen VER
# 33   Great Britain 2022-07-03     Carlos Sainz SAI
# 34       Singapore 2023-09-17     Carlos Sainz SAI
# 35          Brazil 2022-11-13   George Russell RUS
#
#                            Car  Laps         Time         DOB NATIONALITY  \
# 0                      Ferrari    57  1:37:33.584  10/16/1997  Monegasque
# 1                      Ferrari    58  1:27:46.548  10/16/1997  Monegasque
# 2                      Ferrari    71  1:24:24.312  10/16/1997  Monegasque
# 3         Red Bull Racing RBPT    50  1:24:19.293   9/30/1997       Dutch
# 4         Red Bull Racing RBPT    63  1:32:07.986   9/30/1997       Dutch
# 5         Red Bull Racing RBPT    57  1:34:24.258   9/30/1997       Dutch
# 6         Red Bull Racing RBPT    66  1:37:20.475   9/30/1997       Dutch
# 7         Red Bull Racing RBPT    51  1:34:05.941   9/30/1997       Dutch
# 8         Red Bull Racing RBPT    70  1:36:21.757   9/30/1997       Dutch
# 9         Red Bull Racing RBPT    53  1:30:02.112   9/30/1997       Dutch
# 10        Red Bull Racing RBPT    70  1:39:35.912   9/30/1997       Dutch
# 11        Red Bull Racing RBPT    44  1:25:52.894   9/30/1997       Dutch
# 12        Red Bull Racing RBPT    72  1:36:42.773   9/30/1997       Dutch
# 13        Red Bull Racing RBPT    53  1:20:27.511   9/30/1997       Dutch
# 14        Red Bull Racing RBPT    28  3:01:44.004   9/30/1997       Dutch
# 15        Red Bull Racing RBPT    56  1:42:11.687   9/30/1997       Dutch
# 16        Red Bull Racing RBPT    71  1:38:36.729   9/30/1997       Dutch
# 17        Red Bull Racing RBPT    58  1:27:45.914   9/30/1997       Dutch
# 18  Red Bull Racing Honda RBPT    57  1:33:56.736   9/30/1997       Dutch
# 19  Red Bull Racing Honda RBPT    58  2:32:38.371   9/30/1997       Dutch
# 20  Red Bull Racing Honda RBPT    57  1:27:38.241   9/30/1997       Dutch
# 21  Red Bull Racing Honda RBPT    78  1:48:51.980   9/30/1997       Dutch
# 22  Red Bull Racing Honda RBPT    66  1:27:57.940   9/30/1997       Dutch
# 23  Red Bull Racing Honda RBPT    70  1:33:58.348   9/30/1997       Dutch
# 24  Red Bull Racing Honda RBPT    71  1:25:33.607   9/30/1997       Dutch
# 25  Red Bull Racing Honda RBPT    52  1:25:16.938   9/30/1997       Dutch
# 26  Red Bull Racing Honda RBPT    70  1:38:08.634   9/30/1997       Dutch
# 27  Red Bull Racing Honda RBPT    44  1:22:30.450   9/30/1997       Dutch
# 28  Red Bull Racing Honda RBPT    72  2:24:04.411   9/30/1997       Dutch
# 29  Red Bull Racing Honda RBPT    51  1:13:41.143   9/30/1997       Dutch
# 30  Red Bull Racing Honda RBPT    53  1:30:58.421   9/30/1997       Dutch
# 31  Red Bull Racing Honda RBPT    57  1:27:39.168   9/30/1997       Dutch
# 32  Red Bull Racing Honda RBPT    56  1:35:21.362   9/30/1997       Dutch
# 33                     Ferrari    52  2:17:50.311  09-01-1994     Spanish
# 34                     Ferrari    62  1:46:37.418  09-01-1994     Spanish
# 35                    Mercedes    71  1:38:34.044   2/15/1998     British
#
#                                                   URL
# 0        http://en.wikipedia.org/wiki/Charles_Leclerc
# 1        http://en.wikipedia.org/wiki/Charles_Leclerc
# 2        http://en.wikipedia.org/wiki/Charles_Leclerc
# 3         http://en.wikipedia.org/wiki/Max_Verstappen
# 4         http://en.wikipedia.org/wiki/Max_Verstappen
# 5         http://en.wikipedia.org/wiki/Max_Verstappen
# 6         http://en.wikipedia.org/wiki/Max_Verstappen
# 7         http://en.wikipedia.org/wiki/Max_Verstappen
# 8         http://en.wikipedia.org/wiki/Max_Verstappen
# 9         http://en.wikipedia.org/wiki/Max_Verstappen
# 10        http://en.wikipedia.org/wiki/Max_Verstappen
# 11        http://en.wikipedia.org/wiki/Max_Verstappen
# 12        http://en.wikipedia.org/wiki/Max_Verstappen
# 13        http://en.wikipedia.org/wiki/Max_Verstappen
# 14        http://en.wikipedia.org/wiki/Max_Verstappen
# 15        http://en.wikipedia.org/wiki/Max_Verstappen
# 16        http://en.wikipedia.org/wiki/Max_Verstappen
# 17        http://en.wikipedia.org/wiki/Max_Verstappen
# 18        http://en.wikipedia.org/wiki/Max_Verstappen
# 19        http://en.wikipedia.org/wiki/Max_Verstappen
# 20        http://en.wikipedia.org/wiki/Max_Verstappen
# 21        http://en.wikipedia.org/wiki/Max_Verstappen
# 22        http://en.wikipedia.org/wiki/Max_Verstappen
# 23        http://en.wikipedia.org/wiki/Max_Verstappen
# 24        http://en.wikipedia.org/wiki/Max_Verstappen
# 25        http://en.wikipedia.org/wiki/Max_Verstappen
# 26        http://en.wikipedia.org/wiki/Max_Verstappen
# 27        http://en.wikipedia.org/wiki/Max_Verstappen
# 28        http://en.wikipedia.org/wiki/Max_Verstappen
# 29        http://en.wikipedia.org/wiki/Max_Verstappen
# 30        http://en.wikipedia.org/wiki/Max_Verstappen
# 31        http://en.wikipedia.org/wiki/Max_Verstappen
# 32        http://en.wikipedia.org/wiki/Max_Verstappen
# 33      http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.
# 34      http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.
# 35  http://en.wikipedia.org/wiki/George_Russell_%2...

# %%
result_df.to_csv("f1_race_results_web_source.csv",index = False)
